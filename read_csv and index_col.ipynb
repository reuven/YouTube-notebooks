# %%
import pandas as pd

# %%
df = pd.read_csv('titanic3.csv')

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1310, step=1)

# %%
# I want to set the ticket number ("ticket" column) to be the index

df = df.set_index('ticket')
df
# Out:
#         pclass  survived                                             name  \
# ticket
# 24160      1.0       1.0                    Allen, Miss. Elisabeth Walton
# 113781     1.0       1.0                   Allison, Master. Hudson Trevor
# 113781     1.0       0.0                     Allison, Miss. Helen Loraine
# 113781     1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 113781     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...        ...       ...                                              ...
# 2665       3.0       0.0                            Zabour, Miss. Thamine
# 2656       3.0       0.0                        Zakarian, Mr. Mapriededer
# 2670       3.0       0.0                              Zakarian, Mr. Ortin
# 315082     3.0       0.0                               Zimmerman, Mr. Leo
# NaN        NaN       NaN                                              NaN
#
# ...

# %%
df.loc['113781']
# Out:
#         pclass  survived                                             name  \
# ticket
# 113781     1.0       1.0                   Allison, Master. Hudson Trevor
# 113781     1.0       0.0                     Allison, Miss. Helen Loraine
# 113781     1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 113781     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 113781     1.0       1.0                             Cleaver, Miss. Alice
# 113781     1.0       1.0                             Daniels, Miss. Sarah
#
#            sex      age  sibsp  parch    fare    cabin embarked boat   body  \
# ticket
# 113781    male   0.9167    1.0    2.0  151.55  C22 C26        S   11    NaN
# 113781  female   2.0000    1.0    2.0  151.55  C22 C26        S  NaN    NaN
# 113781    male  30.0000    1.0    2.0  151.55  C22 C26        S  NaN  135.0
# 113781  female  25.0000    1.0    2.0  151.55  C22 C26        S  NaN    NaN
# ...

# %%
df = pd.read_csv('titanic3.csv',
                index_col='ticket')
df
# Out:
#         pclass  survived                                             name  \
# ticket
# 24160      1.0       1.0                    Allen, Miss. Elisabeth Walton
# 113781     1.0       1.0                   Allison, Master. Hudson Trevor
# 113781     1.0       0.0                     Allison, Miss. Helen Loraine
# 113781     1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 113781     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...        ...       ...                                              ...
# 2665       3.0       0.0                            Zabour, Miss. Thamine
# 2656       3.0       0.0                        Zakarian, Mr. Mapriededer
# 2670       3.0       0.0                              Zakarian, Mr. Ortin
# 315082     3.0       0.0                               Zimmerman, Mr. Leo
# NaN        NaN       NaN                                              NaN
#
# ...

# %%
df = pd.read_csv('titanic3.csv',
                index_col=7)
df
# Out:
#         pclass  survived                                             name  \
# ticket
# 24160      1.0       1.0                    Allen, Miss. Elisabeth Walton
# 113781     1.0       1.0                   Allison, Master. Hudson Trevor
# 113781     1.0       0.0                     Allison, Miss. Helen Loraine
# 113781     1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 113781     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...        ...       ...                                              ...
# 2665       3.0       0.0                            Zabour, Miss. Thamine
# 2656       3.0       0.0                        Zakarian, Mr. Mapriededer
# 2670       3.0       0.0                              Zakarian, Mr. Ortin
# 315082     3.0       0.0                               Zimmerman, Mr. Leo
# NaN        NaN       NaN                                              NaN
#
# ...

# %%
# what if I want to have a multi-index? I want both ticket and cabin to be the index

df = pd.read_csv('titanic3.csv',
                index_col=['ticket', 'cabin'])
df
# Out:
#                 pclass  survived  \
# ticket cabin
# 24160  B5          1.0       1.0
# 113781 C22 C26     1.0       1.0
#        C22 C26     1.0       0.0
#        C22 C26     1.0       0.0
#        C22 C26     1.0       0.0
# ...                ...       ...
# 2665   NaN         3.0       0.0
# 2656   NaN         3.0       0.0
# 2670   NaN         3.0       0.0
# 315082 NaN         3.0       0.0
# NaN    NaN         NaN       NaN
#
#                                                            name     sex  \
# ticket cabin
# 24160  B5                         Allen, Miss. Elisabeth Walton  female
# 113781 C22 C26                   Allison, Master. Hudson Trevor    male
#        C22 C26                     Allison, Miss. Helen Loraine  female
#        C22 C26             Allison, Mr. Hudson Joshua Creighton    male
#        C22 C26  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...                                                         ...     ...
# ...

# %%
df.loc['113781']
# Out:
#          pclass  survived                                             name  \
# cabin
# C22 C26     1.0       1.0                   Allison, Master. Hudson Trevor
# C22 C26     1.0       0.0                     Allison, Miss. Helen Loraine
# C22 C26     1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# C22 C26     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# NaN         1.0       1.0                             Cleaver, Miss. Alice
# NaN         1.0       1.0                             Daniels, Miss. Sarah
#
#             sex      age  sibsp  parch    fare embarked boat   body  \
# cabin
# C22 C26    male   0.9167    1.0    2.0  151.55        S   11    NaN
# C22 C26  female   2.0000    1.0    2.0  151.55        S  NaN    NaN
# C22 C26    male  30.0000    1.0    2.0  151.55        S  NaN  135.0
# C22 C26  female  25.0000    1.0    2.0  151.55        S  NaN    NaN
# NaN      female  22.0000    0.0    0.0  151.55        S   11    NaN
# ...

# %%
df = pd.read_csv('taxi.csv')
df
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0            2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1            2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2            2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3            2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4            1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
# ...        ...                  ...                   ...              ...
# 9994         1  2015-06-01 00:12:59   2015-06-01 00:24:18                1
# 9995         1  2015-06-01 00:12:59   2015-06-01 00:28:16                1
# 9996         2  2015-06-01 00:13:00   2015-06-01 00:37:25                1
# 9997         2  2015-06-01 00:13:02   2015-06-01 00:19:10                6
# 9998         1  2015-06-01 00:13:04   2015-06-01 00:36:33                1
#
# ...

# %%
df = pd.read_csv('taxi.csv',
                index_col='tpep_pickup_datetime',
                parse_dates=['tpep_pickup_datetime'])
df
# Out:
#                       VendorID tpep_dropoff_datetime  passenger_count  \
# tpep_pickup_datetime
# 2015-06-02 11:19:29          2   2015-06-02 11:47:52                1
# 2015-06-02 11:19:30          2   2015-06-02 11:27:56                1
# 2015-06-02 11:19:31          2   2015-06-02 11:30:30                1
# 2015-06-02 11:19:31          2   2015-06-02 11:39:02                1
# 2015-06-02 11:19:32          1   2015-06-02 11:32:49                1
# ...                        ...                   ...              ...
# 2015-06-01 00:12:59          1   2015-06-01 00:24:18                1
# 2015-06-01 00:12:59          1   2015-06-01 00:28:16                1
# 2015-06-01 00:13:00          2   2015-06-01 00:37:25                1
# 2015-06-01 00:13:02          2   2015-06-01 00:19:10                6
# 2015-06-01 00:13:04          1   2015-06-01 00:36:33                1
#
#                       trip_distance  pickup_longitude  pickup_latitude  \
# tpep_pickup_datetime
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2015-06-02 11:19:29', '2015-06-02 11:19:30',
#                '2015-06-02 11:19:31', '2015-06-02 11:19:31',
#                '2015-06-02 11:19:32', '2015-06-02 11:19:33',
#                '2015-06-02 11:19:34', '2015-06-02 11:19:35',
#                '2015-06-02 11:19:36', '2015-06-02 11:19:38',
#                ...
#                '2015-06-01 00:13:41', '2015-06-01 00:13:42',
#                '2015-06-01 00:13:43', '2015-06-01 00:13:45',
#                '2015-06-01 00:13:47', '2015-06-01 00:12:59',
#                '2015-06-01 00:12:59', '2015-06-01 00:13:00',
#                '2015-06-01 00:13:02', '2015-06-01 00:13:04'],
#               dtype='datetime64[ns]', name='tpep_pickup_datetime', length=9999, freq=None)

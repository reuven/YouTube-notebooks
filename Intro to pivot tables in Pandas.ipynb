# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
df = pd.read_csv('/Users/reuven/Courses/Current/data/olympic_athlete_events.csv')

# %%
df.shape
# Out:
# (271116, 15)

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# what was the average height of Olympic athletes?
df['Height'].mean()
# Out:
# 175.33896987366376

# %%
# what was the average height of Olympic athletes, per year?
df.groupby('Year')['Height'].mean()
# Out:
# Year
# 1896    172.739130
# 1900    176.637931
# 1904    175.788732
# 1906    178.206226
# 1908    177.543158
# 1912    177.447989
# 1920    175.752282
# 1924    174.963039
# 1928    175.162051
# 1932    174.220115
# 1936    175.723993
# 1948    176.172797
# 1952    174.138940
# 1956    173.900968
# 1960    173.141286
# 1964    173.448574
# 1968    173.945865
# 1972    174.565363
# 1976    174.920528
# 1980    175.527488
# 1984    175.540855
# 1988    175.745252
# 1992    176.174649
# 1994    175.169862
# 1996    175.895121
# 1998    174.581369
# 2000    176.089721
# 2002    174.702451
# 2004    175.972850
# 2006    174.623172
# 2008    176.211062
# 2010    174.918182
# 2012    176.262469
# 2014    174.816670
# 2016    176.034266
# Name: Height, dtype: float64

# %%
# What was the average height of athletes, per year *AND* per country?
# for each distinct year -- categorical data
# for each distinct team -- categorical data
# what was the average height?

# we can create a pivot table!

df.pivot_table(index='Year', columns='Team', values='Height').dropna(thresh=10)
# Out:
# Team  30. Februar   Acipactli  Afghanistan  Akatonbo  Alain IV     Albania  \
# Year
# 1900          NaN         NaN          NaN       NaN       NaN         NaN
# 1904          NaN         NaN          NaN       NaN       NaN         NaN
# 1906          NaN         NaN          NaN       NaN       NaN         NaN
# 1908          NaN         NaN          NaN       NaN       NaN         NaN
# 1912          NaN         NaN          NaN       NaN       NaN         NaN
# 1920          NaN         NaN          NaN       NaN       NaN         NaN
# 1924          NaN         NaN          NaN       NaN       NaN         NaN
# 1928          NaN         NaN          NaN       NaN       NaN         NaN
# 1932          NaN         NaN          NaN       NaN       NaN         NaN
# 1936          NaN         NaN          NaN       NaN       NaN         NaN
# 1948          NaN         NaN          NaN       NaN       NaN         NaN
# ...

# %%
df.pivot_table(index='Year', columns='Sport', values='Height').dropna(thresh=30)
# Out:
# Sport  Alpine Skiing     Archery  Art Competitions   Athletics   Badminton  \
# Year
# 1964      169.783784         NaN               NaN  175.876506         NaN
# 1968      171.181360         NaN               NaN  176.355755         NaN
# 1972      170.952681  172.215054               NaN  175.936145         NaN
# 1976      171.251282  170.796875               NaN  176.658613         NaN
# 1980      171.365741  172.651515               NaN  176.641509         NaN
# 1984      172.958944  171.663462               NaN  175.800367         NaN
# 1988      173.618357  172.648221               NaN  175.551587         NaN
# 1992      174.500000  174.095238               NaN  176.087613  174.051546
# 1996             NaN  173.757764               NaN  176.476684  175.128319
# 2000             NaN  174.058824               NaN  176.537860  173.920000
# 2004             NaN  173.731132               NaN  176.301748  173.595000
# ...

# %%
# I want the max, not the mean!
df.pivot_table(index='Year', columns='Sport', values='Height', aggfunc='max').dropna(thresh=30)
# Out:
# Sport  Alpine Skiing  Archery  Art Competitions  Athletics  Badminton  \
# Year
# 1964           187.0      NaN               NaN      202.0        NaN
# 1968           193.0      NaN               NaN      203.0        NaN
# 1972           193.0    189.0               NaN      202.0        NaN
# 1976           188.0    185.0               NaN      202.0        NaN
# 1980           188.0    188.0               NaN      202.0        NaN
# 1984           192.0    188.0               NaN      208.0        NaN
# 1988           192.0    195.0               NaN      203.0        NaN
# 1992           192.0    195.0               NaN      203.0      193.0
# 1996             NaN    191.0               NaN      207.0      199.0
# 2000             NaN    197.0               NaN      205.0      199.0
# 2004             NaN    197.0               NaN      207.0      193.0
# 2008             NaN    193.0               NaN      206.0      195.0
# ...

# %%
# multiple functions
df.pivot_table(index='Year', columns='Sport', values='Height', aggfunc=['mean', 'max']).dropna(thresh=30)
# Out:
#                mean                                                       \
# Sport Alpine Skiing     Archery Art Competitions   Athletics   Badminton
# Year
# 1908            NaN         NaN              NaN  178.305994         NaN
# 1920            NaN         NaN              NaN  177.161194         NaN
# 1924            NaN         NaN       173.555556  176.324257         NaN
# 1928            NaN         NaN       169.000000  176.472505         NaN
# 1932            NaN         NaN       174.952381  176.091765         NaN
# 1936     169.250000         NaN       180.666667  177.456110         NaN
# 1948     170.116279         NaN       176.000000  177.423290         NaN
# 1952     173.387755         NaN              NaN  176.394947         NaN
# 1956     169.338028         NaN              NaN  176.184132         NaN
# 1960     168.188119         NaN              NaN  176.420245         NaN
# 1964     169.783784         NaN              NaN  175.876506         NaN
# ...
